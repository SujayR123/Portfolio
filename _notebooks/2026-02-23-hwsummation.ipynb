# %% [markdown]
# ---
# layout: post
# codemirror: true
# microblog: true
# title: HW Summation
# description: Full HW Summation
# permalink: /js/hw-summation
# author: sujay
# ---

# %% [markdown]
# ## Homeworks
#
# - [Iteration](https://sujayr123.github.io/Portfolio/js/iterationhw)
# - [Booleans](https://sujayr123.github.io/Portfolio/js/booleans)
# - [Data Abstractions](https://sujayr123.github.io/Portfolio/js/dataabstraction)
# - [Math](https://sujayr123.github.io/Portfolio/js/math)
# - [JSON](https://sujayr123.github.io/Portfolio/js/json)
# - [Nested Conditionals](https://sujayr123.github.io/Portfolio/js/nested-conditionals)
# - [Strings](https://sujayr123.github.io/Portfolio/js/strings-hw)

# %%
# %%js
# // CODE_RUNNER: Iterations HW
# let fruits = ["apple", "banana", "orange", "grape"];
#
# console.log("My array of fruits:");
# console.log(fruits);
# console.log();
#
# console.log("First fruit (index 0):", fruits[0]);
# console.log("Third fruit (index 2):", fruits[2]);
# console.log();
#
#
# console.log("Number of fruits:", fruits.length);

# %%
# %%js
# // CODE_RUNNER: JSON HW
# // 1. Create the resume object
# const resume = {
#     fullName: "Sujay",
#     email: "sjrsujay@gmail.com",
#     education: "9th Grade",
#     address: {
#         city: "San Diego",
#         state: "California",
#         country: "USA"
#     },
#     skills: ["Baseball", "Math", "Problem Solving"]
# };
#
# // 2. Access and display properties using dot notation
# console.log("Full Name:", resume.fullName);
# console.log("Email:", resume.email);
# console.log("City:", resume.address.city);
#
# // 3. Convert the JavaScript object to a JSON string
# const jsonString = JSON.stringify(resume);
# console.log("JSON String:", jsonString);
#
# // 4. Parse the JSON string back into a JavaScript object
# const parsedResume = JSON.parse(jsonString);
# console.log("Parsed Resume Object:", parsedResume);

# %%
# %%js
# //CODE_RUNNER: DataAbstraction HW 1
# function calculator(num1, num2, operator) {
#     let result;
#
#     if (operator === "+") {
#         result = num1 + num2;
#     } else if (operator === "-") {
#         result = num1 - num2;
#     } else if (operator === "*") {
#         result = num1 * num2;
#     } else if (operator === "/") {
#         result = num1 / num2;
#     } else {
#         result = "Invalid operator";
#     }
#
#     return result;
# }
#
# console.log(calculator(10, 5, "+"));
# console.log(calculator(10, 5, "-"));
# console.log(calculator(10, 5, "*"));
# console.log(calculator(10, 5, "/"));

# %%
# %%js
# // CODE_RUNNER: Data Abstraction HW 2
# class Pet {
#     eat() {
#         console.log("Nom nom nom");
#     }
# }
#
# // Create the Dog class that extends Pet
# class Dog extends Pet {
#     bark() {
#         console.log("Woof woof!");
#     }
# }
#
# // (Optional test)
# let myDog = new Dog();
# myDog.eat();   // Nom nom nom
# myDog.bark();  // Woof woof!

# %%
# %%js
# // CODE_RUNNER: Strings HW
# let str1 = "Hi";
# let str2 = "JavaScript";
# let str3 = "Programming is fun";
#
# // Length of each string
# console.log(`Length of str1: ${str1.length}`);
# console.log(`Length of str2: ${str2.length}`);
# console.log(`Length of str3: ${str3.length}`);
#
# // First and last character of each string
# console.log(`First character of str1: ${str1[0]}`);
# console.log(`Last character of str1: ${str1[str1.length - 1]}`);
#
# console.log(`First character of str2: ${str2[0]}`);
# console.log(`Last character of str2: ${str2[str2.length - 1]}`);
#
# console.log(`First character of str3: ${str3[0]}`);
# console.log(`Last character of str3: ${str3[str3.length - 1]}`);
#
# // Sentence using interpolation (NOT concatenation)
# console.log(`My three strings are: ${str1}, ${str2}, and ${str3}.`);

# %%
# %%js
#
# // CODE_RUNNER: Homework Problem #1 MATH
#
# let y = 25; // you can change this number
#
# if (y % 5 === 0) {
#     console.log(y + " is divisible by 5");
# } else {
#     console.log(y + " is not divisible by 5");
# }

# %%
# %%js
#
# // CODE_RUNNER: Homework Problem #2 MATH
#
# let a = 10;
# let b = 20;
# let sum = a + b;
#
# console.log("The sum is: " + sum);

# %%
# %%js
# // CODE_RUNNER: Boolean Logic HW
#
# function isPositiveAndEven(num) {
#     let isPositive = num > 0;
#     let isEven = num % 2 === 0;
#     return isPositive && isEven;
# }
#
# console.log(isPositiveAndEven(8)); // true

# %%
# %%js
# // CODE_RUNNER: Homework Nested Conditionals
# for (let num = 1; num <= 50; num++) {
#     console.log(`Number: ${num}`);
#
#     if (num % 1 === 0) { // always true, but included as a factor
#         if (num % 2 === 0) {
#             if (num % 5 === 0) {
#                 if (num % 10 === 0) {
#                     if (num % 25 === 0) {
#                         if (num % 50 === 0) {
#                             console.log("  Divisible by: 1, 2, 5, 10, 25, 50");
#                         } else {
#                             console.log("  Divisible by: 1, 2, 5, 10, 25");
#                         }
#                     } else {
#                         console.log("  Divisible by: 1, 2, 5, 10");
#                     }
#                 } else {
#                     console.log("  Divisible by: 1, 2, 5");
#                 }
#             } else {
#                 console.log("  Divisible by: 1, 2");
#             }
#         } else {
#             console.log("  Divisible by: 1");
#         }
#     }
# }

# %%
# %%js
#
# //CODE_RUNNER: Homework Challenge - Create a class and make 2 different methods.CLASSES AND METHODS
#
# class Dog {
#   bark() {
#     console.log("Woof!");
#   }
#
#   fetch() {
#     console.log("The dog fetches the ball!");
#   }
# }
#
# const myDog = new Dog();
# myDog.bark();   // Woof!
# myDog.fetch();  // The dog fetches the ball!
